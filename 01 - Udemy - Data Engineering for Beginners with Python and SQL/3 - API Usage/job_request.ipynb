# %%
# %pip install pandas
# %pip install openpyxl
# Out:
# Requirement already satisfied: pandas in c:\users\esteban.vergara\appdata\local\programs\python\python313\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\esteban.vergara\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\esteban.vergara\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\esteban.vergara\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\esteban.vergara\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\esteban.vergara\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from datetime import datetime

# %%
import requests

url = "https://www.arbeitnow.com/api/job-board-api"

payload = {}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

data = response.json()

# %%
data["data"]
# Out:
# [{'slug': 'junior-customer-care-manager-remote-aus-deutschland-munich-248915',
#   'company_name': 'Alphapet Ventures GmbH',
#   'title': 'Junior Customer Care Manager (m/w/d) - Remote aus Deutschland',
#   'description': '<h2>Deine Aufgaben</h2>\n<p>Du bist auf der Suche nach einem Einstieg in den Bereich Customer Care? Wir suchen einen engagierten Junior Customer Care Manager (m/w/d), der unser dynamisches Team remote aus Deutschland verstärkt.  </p>\n<ul>\n<li>Sei das freundliche Gesicht unseres Unternehmens und sorge durch deine serviceorientierte Herangehensweise für eine exzellente Kundenerfahrung</li>\n<li>Bearbeite eigenständig Standard-Anfragen unserer Kunden per Telefon, Chat und E-Mail</li>\n<li>Stehe in engem Kontakt mit internen Abteilungen, um Kundenanliegen effizient zu lösen</li>\n<li>Identifiziere Wachstums- und Optimierungspotenziale und bringe proaktiv Lösungsvorschläge ein</li>\n</ul>\n<h2>Was Du mitbringst</h2>\n<ul>\n<li>Erste Erfahrungen im Kundensupport oder ähnlichen Kundenkontaktbereichen</li>\n<li>Kenntnisse in der Arbeit mit Ticketsystemen (z.B. Freshworks) von Vorteil</li>\n<li>Eine ausgeprägte Kundenorientierung und empathische Denkweise</li>\n<li>Starke Kommunikationsfähigkeiten auf allen Ebenen, intern und extern</li>\n<li>Selbstständige Arbeitsweise und unternehmerisches Denken</li>\n</ul>\n<h2>Was wir Dir bieten</h2>\n<ul>\n<li>Verantwortungsvolle, spannende und abwechslungsreiche Aufgaben mit <strong>viel Gestaltungsspielraum</strong> in einem <strong>dynamischen Unternehmen</strong>, das flache Hierarchien und eine offene, lockere Arbeitsatmosphäre lebt, in der alle per "Du" sind</li>\n<li>Ein <strong>freundliches, offenes Team</strong> bestehend aus ca. 280 Mitarbeitenden in München, Leipzig und Albourne (UK) mit mehreren lieben <strong>Bürohunden</strong> an unseren Standorten</li>\n<li><strong>Flexible Arbeitszeiten</strong> (die auf Vertrauensarbeitszeit basieren), <strong>Home-Office</strong> Optionen inkl. <strong>Kostenbeteiligung an Deiner Home-Office Ausstattung</strong> und die Möglichkeit, für mehrere Monate <strong>aus dem Ausland zu arbeiten</strong></li>\n<li><strong>28 Tage Urlaubsanspruc</strong> <strong>h</strong> sowie die Möglichkeit, <strong>bis zu 20 Tage unbezahlten Urlaub</strong> sowie <strong>Sonderurlaub</strong> zu nehmen!</li>\n<li>Verschiedene interne &#x26; externe <strong>Weiterentwicklungsmöglichkeiten</strong>, die Du eigenständig nach Deinen Interessen auswählen kannst</li>\n<li>Deine <strong>mentale Gesundheit</strong> ist uns wichtig! Deshalb kannst Du im Rahmen der Plattform "<strong>OpenUp</strong>" anonym an Einzel- oder Gruppentherapie-Sitzungen teilnehmen oder in 1:1 Meetings <strong>mit echten Therapeuten sprechen</strong></li>\n<li>Verschiedene <strong>Mitarbeiterrabatte</strong> - für Mensch und Tier!</li>\n<li>Regelmäßige Team-, Company- und Family &#x26; Friends-<strong>Events</strong></li>\n<li>Du brauchst eine Pause? Entspanne Dich in unserer <strong>Social-Area</strong>, die mit einem Kicker ausgestattet ist oder fordere Deine Kollegen auf unserer gemütlichen Sofalandschaft zu einem Mario Kart-Battle (oder einem anderen Nintendo Switch Spiel) heraus!</li>\n<li>Aufgewärmtes Essen magst Du nicht? Essen bestellen dauert Dir zu lange? In unserem Büro steht Dir eine hochwertige, vollausgestattete Küche zur Verfügung in der Du den Kochlöffel schwingen oder tolle Kuchen zaubern kannst!</li>\n<li>Kaffee, Kakao, Tee und weitere kühle Softdrinks wie Wasser und Säfte sowie frisches Obst, kleinere Snacks und eine prall gefüllte Süßigkeiten-Schublade stehen Dir kostenlos zur Verfügung</li>\n<li><strong>Viele weitere, großartige Benefits</strong> die wir Dir gerne im Rahmen des Recruitingprozesses näher vorstellen!</li>\n</ul>\n<h2>Interesse ?</h2>\n<p>Dann freuen wir uns auf Deine Bewerbung mit Lebenslauf und Anschreiben inkl. Angabe Deines frühestmöglichen Startdatums bzw. Deiner Kündigungsfrist sowie Deiner Gehaltsvorstellung.</p>\n<p>Find more <a href="https://www.arbeitnow.com/english-speaking-jobs">English Speaking Jobs in Germany</a> on Arbeitnow</a>',
#   'remote': True,
#   'url': 'https://www.arbeitnow.com/jobs/companies/alphapet-ventures-gmbh/junior-customer-care-manager-remote-aus-deutschland-munich-248915',
#   'tags': ['Remote', 'Customer Service'],
#   'job_types': ['berufseinstieg'],
#   'location': 'Munich',
#   'created_at': 1739821745},
#  {'slug': 'praktikum-im-online-marketing-3-6-monate-cologne-321932',
#   'company_name': 'niostem',
#   'title': 'Praktikum im Online Marketing (3-6 Monate)',
#   'description': '<ul>\n<li>Wir sind ein Start-up aus Köln und haben das weltweit erste Gerät zur Umkehrung von Haarausfall entwickelt</li>\n<li>Unser Ansatz ist revolutionär und basiert auf eigener Forschung am Max-Planck-Institut</li>\n<li>Die Technologie wird das Leben von Millionen von Menschen verbessern, sei ein Teil davon!</li>\n</ul>\n<h2>Aufgaben</h2>\n<ul>\n<li>Unterstützung der Kommunikationsstrategie</li>\n<li>SEO Artikel schreiben</li>\n<li>Influencern Sourcing &#x26; Beaufttragung</li>\n<li>Community-Management </li>\n<li>E-Mail Marketing</li>\n<li>Content Strategie mitentwicklen</li>\n</ul>\n<h2>Qualifikation</h2>\n<ul>\n<li>Bachelor / Master Student mit Schwerpunkt Marketing </li>\n<li>Idealerweise vorherige Marketingerfahrung </li>\n<li>Starke Deutsch &#x26; Englisch Kenntnisse</li>\n</ul>\n<h2>Benefits</h2>\n<ul>\n<li>Hybrides Arbeiten</li>\n<li>Viel Eigenverantwortung</li>\n<li><strong>Steile Lernkurve</strong></li>\n<li>Maximal Gute Zeit mit einem Top Team</li>\n</ul>\n<p>Wir freuen uns auf dich!</p>\n<p>Find more <a href="https://www.arbeitnow.com/english-speaking-jobs">English Speaking Jobs in Germany</a> on Arbeitnow</a>',
#   'remote': False,
#   'url': 'https://www.arbeitnow.com/jobs/companies/niostem/praktikum-im-online-marketing-3-6-monate-cologne-321932',
#   'tags': ['Online Marketing'],
#   'job_types': ['Internship', 'hilfstätigkeit / student'],
#   'location': 'Cologne',
#   'created_at': 1739821745},
#  {'slug': 'grafikdesignerin-5-jahre-erfahrung-cologne-30003',
#   'company_name': 'niostem',
#   'title': 'Grafikdesigner:in (+5 Jahre Erfahrung)',
#   'description': '<ul>\n<li>Wir sind ein Start-up aus Köln und haben das weltweit erste Gerät für Haarwuchs entwickelt und bereiten gerade den <strong>Full Launch</strong> vor</li>\n<li>Unser Ansatz ist revolutionär und basiert auf unserer eigenen Forschungen am Max-Planck-Institut</li>\n<li>Die <strong>Technologie wird das Leben von Millionen von Menschen verändern</strong> und Du kannst dabei helfen diese Menschen zu erreichen!</li>\n<li>(Wir präferieren Bewerber die schon in Köln sind, oder bereit sind umzuziehen)</li>\n</ul>\n<h2>Aufgaben</h2>\n<ul>\n<li>Entwicklung von integrierten <strong>Online Kampagnen</strong></li>\n<li><strong>Konzeption</strong> von Content für Socials &#x26; Website</li>\n<li><strong>Design</strong> von Still Content</li>\n<li><strong>Cutten</strong> von Videos (long/shortform) --> vor allem Youtube ist von strategischer Bedeutung für uns</li>\n<li><strong>Brand Identity</strong> durch kohärentes Design stärken</li>\n<li><em>Bonus: UI/UX für Web + App Design</em></li>\n</ul>\n<h2>Qualifikation</h2>\n<ul>\n<li>>3 Jahre Erfahrung als Grafikdesigner / Cutter / Art Director</li>\n<li>Aussagekräftiges Portfolio</li>\n<li><em>Bonus: Erfahrung mit Stills &#x26; Video Content für Online Marketing</em></li>\n<li><em>Bonus: Aufbau von Social Media Accounts</em></li>\n<li><em>Bonus: App Design</em></li>\n</ul>\n<h2>Benefits</h2>\n<ul>\n<li><strong>Anteile (%) am Unternehmen (VSOP)</strong></li>\n<li>Schnell steigendes Gehalt</li>\n<li>Mega dynamisches Team </li>\n<li><strong>Steile Lernkurve und maximale Verantwortung</strong></li>\n</ul>\n<p>Wir freuen uns auf deine Bewerbung!</p>\n<p>Find <a href="https://www.arbeitnow.com/">Jobs in Germany</a> on Arbeitnow</a>',
#   'remote': False,
#   'url': 'https://www.arbeitnow.com/jobs/companies/niostem/grafikdesignerin-5-jahre-erfahrung-cologne-30003',
#   'tags': ['Graphic Arts and Communication Design'],
#   'job_types': ['hilfstätigkeit / student'],
#   'location': 'Cologne',
#   'created_at': 1739821745},
#  {'slug': 'advertising-client-success-manager-remote-berlin-470957',
#   'company_name': 'REPLUG',
#   'title': 'Advertising Client Success Manager  (REMOTE)',
#   'description': '<p>REPLUG is a leading mobile app marketing agency specializing in <strong>OEM advertising</strong> and performance marketing. We help mobile-first companies scale efficiently by leveraging <strong>on-device media buying, data-driven strategies, and deep industry expertise</strong>.</p>\n<p>We are now looking for a <strong>Client Success Manager (CSM) - OEM Advertising</strong> to <strong>own client relationships</strong>, optimize <strong>on-device advertising campaigns</strong>, and drive long-term success for our partners. If you thrive in a <strong>fast-paced, data-driven environment</strong> and enjoy working with <strong>OEM advertising</strong>, <strong>Data</strong>, reporting, and mobile growth strategies, this role is for you.</p>\n<h2>Tasks</h2>\n<p><strong>Client Success &#x26; Account Management</strong></p>\n<p> • Serve as the <strong>primary point of contact</strong> for clients, ensuring their OEM advertising campaigns run smoothly.</p>\n<p> • Build <strong>strong, long-term relationships</strong> with clients, understanding their goals and translating them into actionable advertising strategies.</p>\n<p> • Manage client expectations and provide <strong>proactive recommendations</strong> to maximize <strong>performance and ROI</strong>.</p>\n<p> • Conduct <strong>regular check-ins and performance reviews</strong>, ensuring continuous alignment with client KPIs.</p>\n<p> • Work cross-functionally with internal teams (media buyers, analysts, and creatives) to drive <strong>campaign execution and optimization</strong>. </p>\n<p><strong>OEM Advertising Operations</strong></p>\n<p> • <strong>Oversee the setup, monitoring, and optimization</strong> of OEM ad campaigns across various placements </p>\n<p> • Analyze <strong>campaign performance</strong> and provide actionable insights to improve efficiency and scale.</p>\n<p> • Troubleshoot technical issues and liaise with <strong>OEM partners</strong> to ensure smooth campaign execution.</p>\n<p> • Stay updated on <strong>OEM advertising trends and best practices</strong>, ensuring clients receive <strong>cutting-edge strategies</strong>. </p>\n<p><strong>Data &#x26; Reporting</strong></p>\n<p> • Use <strong>MMP</strong> and other analytics tools to build <strong>custom dashboards and performance reports</strong> for clients.</p>\n<p> • Interpret <strong>campaign data</strong>, identifying patterns, trends, and areas for optimization.</p>\n<p> • Present data-driven insights to clients in a <strong>clear, concise, and actionable</strong> manner.</p>\n<h2>Requirements</h2>\n<p> • <strong>2+ years of experience</strong> in <strong>client success, account management, or advertising operations</strong> within <strong>mobile marketing, AdTech, or performance marketing</strong>.</p>\n<p> • <strong>Strong understanding of OEM advertising</strong> (or experience in mobile UA, programmatic, or paid media).</p>\n<p> • <strong>Excellent communication and relationship-building skills</strong> – ability to <strong>own client relationships</strong> and drive <strong>business impact</strong>.</p>\n<p> • <strong>Data-driven mindset</strong> with experience in <strong>Looker Studio, Google Analytics, or similar analytics tools</strong>.</p>\n<p> • Ability to work in <strong>a fast-paced, remote environment</strong>, managing multiple clients and priorities simultaneously.</p>\n<p> • Proactive, problem-solving attitude with a <strong>passion for mobile growth and digital advertising</strong>.</p>\n<h2>Benefits</h2>\n<p> • A <strong>fully remote</strong> work environment with <strong>flexible hours</strong>.</p>\n<p> • The opportunity to work with <strong>top-tier mobile apps</strong> and <strong>innovative advertising solutions</strong>.</p>\n<p> • A <strong>high-growth environment</strong> where you can take full ownership of client relationships and scale with the company.</p>\n<p> • A yearly budget dedicated for education and self-improvement</p>\n<p>If you’re passio ...
#   'remote': True,
#   'url': 'https://www.arbeitnow.com/jobs/companies/replug/advertising-client-success-manager-remote-berlin-470957',
#   'tags': ['Remote', 'Marketing and Communication'],
#   'job_types': [],
#   'location': 'Berlin',
#   'created_at': 1739818143},
#  {'slug': 'bilanzbuchhalter-steuerfachangestellter-oberhausen-20312',
#   'company_name': 'S&G Energy Group GmbH',
#   'title': 'Bilanzbuchhalter/Steuerfachangestellter (m/w/d)',
#   'description': '<p>Die S&#x26;G Energy Group GmbH ist ein internationaler Anbieter von Energielösungen, der sich auf grüne und nachhaltige Energie spezialisiert hat. Als dezentraler Energieversorger (IPP) fokussieren wir uns auf B2B Energieproduktion und –vertrieb in der Industrie.</p>\n<p>Das renommierte Management Team besteht aus führenden Energie- und Finanzexperten und verfügt über umfassende und langjährige Erfahrung in der Entwicklung, der Finanzierung und dem Bau von Clean Energy Projekten sowie in der Wartung und dem Betrieb der daraus resultierenden Energiesysteme.</p>\n<p>Unser Fokus liegt in den Bereichen Solarenergie. Dabei agieren wir als Asset Manager, der die Fähigkeiten und Ressourcen verschiedener Dienstleister in dieser Industrie bündelt. </p>\n<p>Für unser Tochterunternehmen S&#x26;G Real Asset Structuring GmbH in Frankfurt am Main suchen wir einen Bilanzbuchhalter (m/w/d) oder einen Steuerfachangestellten (m/w/d). Die S&#x26;G Real Asset Structuring GmbH ist auf die Strukturierung und Verwaltung nachhaltiger Energieinvestitionen spezialisiert. Der Fokus liegt dabei auf der effizienten Entwicklung, Finanzierung und dem Management von erneuerbaren Energieprojekten.</p>\n<h2>Aufgaben</h2>\n<ul>\n<li><strong>Finanzbuchhaltung &#x26; Jahresabschluss:</strong></li>\n</ul>\n<p>Eigenverantwortliche Erfassung und Verwaltung aller Geschäftsvorfälle </p>\n<p>Durchführung der Debitoren- und Kreditorenbuchhaltung inklusive Rechnungsprüfung </p>\n<p>Erstellung von Monats- und Jahresabschlüssen nach HGB </p>\n<p>Ermittlung und Verbuchung von Rückstellungen und Abgrenzungen </p>\n<p>Intercompany-Abstimmung sowie Erstellung des Anlagespiegels </p>\n<ul>\n<li><strong>Steuern &#x26; Compliance:</strong> </li>\n</ul>\n<p>Erstellung und Abgabe der Umsatzsteuer-Voranmeldungen sowie der ZM-Meldungen </p>\n<p>Lohnsteuerermittlung und -zahlung </p>\n<p>Ansprechpartner für Finanzbehörden, Wirtschaftsprüfer, Steuerberater und Banken </p>\n<p>Begleitung von Betriebsprüfungen und Umsetzung steuerlicher Anforderungen </p>\n<ul>\n<li><strong>Zahlungsverkehr &#x26; Liquiditätsmanagement:</strong> </li>\n</ul>\n<p>Vorbereitung und Abwicklung des Zahlungsverkehrs </p>\n<p>Erstellung von Liquiditätsplanungen und -analysen </p>\n<ul>\n<li><strong>Controlling &#x26; Reporting:</strong> </li>\n</ul>\n<p>Erstellung von Budgetplanungen, Erfolgsrechnungen und Kalkulationen </p>\n<p>Vorbereitung und Analyse von Investitionsentscheidungen </p>\n<p>Aufbereitung von Finanzberichten für Banken, Investoren und interne Stakeholder </p>\n<p>Entwicklung und Optimierung interner Prozesse, Richtlinien und Buchungssysteme</p>\n<h2>Qualifikation</h2>\n<ul>\n<li>Abgeschlossene kaufmännische Ausbildung mit Weiterbildung zum Bilanzbuchhalter (IHK), Steuerfachangestellten oder ein abgeschlossenes Studium mit Schwerpunkt Rechnungswesen/Finanzen </li>\n<li>Mehrjährige Berufserfahrung im Bereich Finanz- und Rechnungswesen </li>\n<li>Fundierte Kenntnisse im HGB und Steuerrecht </li>\n<li>Sicherer Umgang mit Buchhaltungssoftware (z. B. DATEV, SAP oder ähnliche)  </li>\n<li>Strukturierte, selbstständige und lösungsorientierte Arbeitsweise </li>\n<li>Kommunikationsstärke und Teamfähigkeit </li>\n<li>Sehr gute Deutsch- und Englischkenntnisse in Wort und Schrift</li>\n</ul>\n<h2>Benefits</h2>\n<ul>\n<li>Einen zukunftssicheren Job mit anspruchsvollen Aufgaben und viel Raum für Ideen und Entwicklung.</li>\n<li>Eine starke Unternehmensgruppe mit etabliertem Netzwerk.</li>\n<li>Aktive Mitgestaltung von internationalen spannenden Projekten im Bereich Erneuerbare Energien.</li>\n<li>Überdurchschnittliches Gehalt.</li>\n<li>Flexible Arbeitszeitgestaltung und hybrides Arbeiten.</li>\n<li>Arbeitsort in Frankfurt am Main.</li>\n<li>Eine Unternehmenskultur, die sich durch einen lebendigen Austausch und die prestigefreie Zusammenarbeit zwischen jungen und erfahrenen Fachleuten und verschiedenen Disziplinen auszeichnet.</li>\n</ul>\n<p>Find <a href="https://www.arbeitnow.com/">Jobs  ...
#   'remote': False,
#   'url': 'https://www.arbeitnow.com/jobs/companies/sg-energy-group-gmbh/bilanzbuchhalter-steuerfachangestellter-oberhausen-20312',
#   'tags': ['Finance'],
#   'job_types': ['berufserfahren'],
#   'location': 'Oberhausen',
#   'created_at': 1739818143},
#  {'slug': 'senior-software-developer-fullstack-castrop-rauxel-478526',
#   'company_name': 'Redtree Gmbh',
#   'title': '(Senior) Software Developer - Fullstack (m/w/d)',
#   'description': '<p>Du suchst nach einer neuen beruflichen Herausforderung und möchtest Deine Kenntnisse in einem dynamischen Team einbringen, innovative Projekte umsetzen und dabei die Digitalisierung vorantreiben? Dann bist Du bei uns genau richtig!</p>\n<p><strong>Wir sind Redtree</strong><br>\nEin Technologieunternehmen im Herzen des Ruhrgebiets mit einer klaren Mission: die 360°-Digitalisierung von Stadtwerken und Energieversorgern.<br>\nUnser Team aus erfahrenen Expert:innen entwickelt maßgeschneiderte Softwarelösungen für Vertrieb, Kundenservice, Produktmanagement und Operations – und jetzt brauchen wir Dich, um unsere Projekte noch erfolgreicher zu machen.</p>\n<p>Wir suchen ab sofort Unterstützung durch einen Fullstack Developer (m/w/d) an unserem Standort in Castrop-Rauxel oder Remote.</p>\n<h2>Aufgaben</h2>\n<ul>\n<li><strong>Entwicklung von Fullstack-Anwendungen:</strong> Du bringst Deine Kenntnisse in HTML, CSS/ SASS, JavaScript/ES6, TypeScript und PHP 7 und 8 ein, um moderne Webanwendungen zu entwickeln.</li>\n<li><strong>Arbeiten mit Laravel und VueJS:</strong> Du nutzt Laravel für Backendlösungen und VueJS für dynamische Benutzeroberflächen.</li>\n<li><strong>Erstellung von WordPress-Themes und -Plugins:</strong> Du entwickelst und optimierst individuelle Lösungen für unsere Kunden.</li>\n<li><strong>Datenbank-Management:</strong> Du sorgst für eine optimale Leistung und Integrität in MySQL und PostgreSQL.</li>\n<li><strong>Arbeiten mit Git:</strong> Versionskontrolle gehört für Dich zum Alltag.</li>\n<li><strong>Betreuung von Linux-Umgebungen:</strong> Du unterstützt unsere Systeme und optimierst die Arbeitsabläufe auf Linux-Basis.</li>\n</ul>\n<h2>Qualifikation</h2>\n<ul>\n<li><strong>Fundierte Kenntnisse in HTML, CSS, JavaScript/ES6, TypeScript und PHP 7 sowie 8:</strong><br>\nDein technisches Know-how ermöglicht Dir, moderne Webtechnologien sicher anzuwenden und effiziente Lösungen zu entwickeln.</li>\n<li><strong>Praktische Erfahrung mit Laravel und VueJS:</strong><br>\nDu hast bereits mit diesen Frameworks gearbeitet und kannst anspruchsvolle Anwendungen eigenständig umsetzen.</li>\n<li><strong>Sicherer Umgang mit relationalen Datenbanken:</strong><br>\nMySQL und PostgreSQL sind Dir vertraut, und Du weißt, wie Du Daten effizient strukturierst und verwaltest.</li>\n<li><strong>Erfahrung in der WordPress-Entwicklung:</strong><br>\nDu hast bereits Themes und Plugins entwickelt und kennst Dich in der Anpassung und Erweiterung von WordPress-Projekten aus.</li>\n<li><strong>Routine im Umgang mit Git:</strong><br>\nVersionskontrolle und kollaboratives Arbeiten im Team gehören für Dich zum Arbeitsalltag.</li>\n<li><strong>Kenntnisse in Linux-Systemen:</strong><br>\nDu fühlst Dich in der Linux-Umgebung sicher und kannst administrative Aufgaben übernehmen.</li>\n<li><strong>Strukturierte und lösungsorientierte Arbeitsweise:</strong><br>\nDu gehst Aufgaben analytisch und fokussiert an, findest kreative Lösungen für komplexe Herausforderungen und bist neugierig auf Innovationen und setzt diese schnell und effektiv ein.</li>\n<li><strong>Teamgeist und gute Deutschkenntnisse (mind. B2):</strong><br>\nMit Deiner offenen, klaren Kommunikation trägst Du zu einer produktiven Zusammenarbeit bei und drückst Dich schriftlich wie mündlich sicher und präzise aus, auch in einem professionellen Umfeld.</li>\n</ul>\n<h2>Benefits</h2>\n<ul>\n<li><strong>Flache Hierarchien:</strong> Arbeite eng mit allen Abteilungen und der Geschäftsführung zusammen und bringe Deine Ideen ein.</li>\n<li><strong>Home-Office-Option:</strong> Flexibilität, wo und wie Du arbeitest.</li>\n<li><strong>Modernes Büro:</strong> Für Hundeliebhaber:innen – bring Deinen Vierbeiner gerne mit!</li>\n<li><strong>Teamspirit:</strong> Ein Team, das Dich vom ersten Tag an herzlich willkommen heißt.</li>\n<li><strong>Teamevents:</strong> Gemeinsame Zeit, die nicht nur verbindet, sondern auch Spaß macht.</li>\n<li><strong>Top-Lage:</strong> Eine hervorragende Verkehrs ...
#   'remote': False,
#   'url': 'https://www.arbeitnow.com/jobs/companies/redtree-gmbh/senior-software-developer-fullstack-castrop-rauxel-478526',
#   'tags': ['Software Development'],
#   'job_types': [],
#   'location': 'Castrop-Rauxel',
#   'created_at': 1739818143},
#  {'slug': 'founders-associate-part-time-berlin-459841',
#   'company_name': 'Zapdeck',
#   'title': 'Founders Associate (Part-time)',
#   'description': '<p>Wir bieten eine spannende Position als <strong>Founders Associate in Teilzeit</strong> (2-3 Tage pro Woche) in unserem Berliner Startup.</p>\n<p>Du arbeitest direkt mit unserem Co-Founder und CEO an wichtigen Projekten in den Bereichen Strategie, Sales und Operations. Die Rolle ist ideal für ambitionierte, Startup-interessierte Personen, die Erfahrung im Aufbau eines Startup sammeln möchten – und vielleicht eines Tages ihr eigenes gründen 🚀</p>\n<p><strong>Über Zapdeck</strong></p>\n<p>Professionals verbringen täglich Millionen von Stunden mit der Erstellung von Präsentationen. Zapdeck revolutioniert diese Aufgabe mit einer KI-Software, die es ermöglicht, in wenigen Minuten professionell gestaltete Slides zu generieren.</p>\n<p>Das Herzstück von Zapdeck ist eine innovative KI-Technologie – die erste, die Text direkt in professionelles Slide Design umwandeln kann. Unser Produkt bietet einen intuitiven Editor, mit dem Nutzer ihre Storylines entwickeln und in perfekt gestaltete Slides umwandeln können.</p>\n<p>Präsentationserstellung ist ein mehere Milliarden Dollar großer Markt, der durch Generative AI revolutioniert wird. Mit Zapdeck haben wir eine Pre-Seed-Finanzierung eingesammelt und bauen aktuell Partnerschaften mit führenden Unternehmen der Branche auf.</p>\n<p>Als Teil unseres erfahrenen Teams hast du die Möglichkeit, deine Fähigkeiten schnell weiterzuentwickeln. Unser CEO war zuvor Berater bei BCG und unser CTO war zuvor technischer CPO beim InsurTech-Startup INZMO.</p>\n<h2>Aufgaben</h2>\n<ul>\n<li><strong>Go-to-market:</strong> Neue Leads kontaktieren und Kontakt zu potentiellen Kunden pflegen – darunter einige der weltweit größten Unternehmen der Branche.</li>\n<li><strong>Marketing:</strong> Marketing Content und unseren Newsletter erstellen, bei der Produktion unseres AI Workflows Podcast mitarbeiten.</li>\n<li><strong>Operations:</strong> Potentielle Kunden identifizieren, unsere Warteliste von interessierten Nutzern managen, Team Meetings vorbereiten.</li>\n<li><strong>Customer Success:</strong> Automatisierte Marketing- und Customer-Success-Kanäle einrichten, Feedback von Kunden einholen.</li>\n</ul>\n<h2>Qualifikation</h2>\n<p><strong>Professionelle Anforderungen</strong></p>\n<ul>\n<li>Aktuell Student*in in einem relevanten Master (Business, Marketing, Kommunikation, Psychologie, etc.) oder abgeschlossenes Studium.</li>\n<li>Mindestens 1 Jahr Arbeitserfahrung durch Praktika oder studentische Tätigkeiten, idealerweise in Startups, Beratung oder ähnlichem High-Performance Bereich.</li>\n<li>Strukturiertes Arbeiten und Eigenmotivation: Zum Beispiel durch persönliche Projekte, Führungsrollen in studentischen Organisationen, etc.</li>\n<li>Professionelle Kommunikation für die Interaktion mit wichtigen Stakeholdern wie Kunden oder Investoren.</li>\n</ul>\n<p><strong>Weitere Anforderungen</strong></p>\n<ul>\n<li>Wohnhaft in Berlin / Potsdam – leider können wir keine Bewerbungen aus anderen Teilen der Welt akzeptieren.</li>\n<li>Fließend in Deutsch und Englisch.</li>\n<li>Kurzfristig verfügbar (Einstieg gerne innerhalb weniger Tage)</li>\n</ul>\n<h2>Benefits</h2>\n<ul>\n<li>Möglichkeit einen Einblick in viele Aufgabenbereiche eines Startups zu erhalten und Erfahrung im Aufbau eines Unternehmens zu sammeln.</li>\n<li>Junges Team, in dem du schnell Verantwortung übernehmen kannst und direkt den Impact deiner Arbeit siehst.</li>\n<li>Große Flexibilität in Bezug auf Arbeitszeit und Ort – wir haben einen Office Day pro Woche in unserem Büro in Berlin Mitte, der Rest kann frei gestaltet werden :)</li>\n<li>Faires Gehalt und zusätzliche Erfolgsbeteiligung, wenn wir mit deiner Hilfe neue Kunden akquirieren.</li>\n</ul>\n<p>Find more <a href="https://www.arbeitnow.com/english-speaking-jobs">English Speaking Jobs in Germany</a> on Arbeitnow</a>',
#   'remote': False,
#   'url': 'https://www.arbeitnow.com/jobs/companies/zapdeck/founders-associate-part-time-berlin-459841',
#   'tags': ['Business Development'],
#   'job_types': ['Working student', 'hilfstätigkeit / student'],
#   'location': 'Berlin',
#   'created_at': 1739818143},
#  {'slug': 'technischer-support-fur-privatpersonen-40eur-h-trier-233211',
#   'company_name': 'HELFERLINE GmbH',
#   'title': 'Technischer Support für Privatpersonen (40€/h) - Trier',
#   'description': '<p>Wir, die HELFERLINE GmbH, sind ein innovatives Start-Up und suchen smarte Helferlein, die Privatpersonen bei alltäglichen Technikproblemen unterstützen können. Mit unserer HELFERLINE-App kannst du ganz einfach Aufträge abrufen und annehmen. Die Aufträge finden immer bei den Kunden zu Hause statt. Es handelt sich also nicht um Remote-Einsätze. Je nach Wohnort gibt es hier meist eine Anfahrtspauschale.</p>\n<h2>Aufgaben</h2>\n<p>Die Probleme sind in verschiedene Kategorien unterteilt: Windows, Android, iOS, macOS, Internet, Drucker und TV. Bei einem ersten Gespräch mit uns werden wir gemeinsam entscheiden, welche Bereiche dir am besten liegen, damit du nur passende Aufträge angezeigt bekommst.</p>\n<h2>Qualifikation</h2>\n<ul>\n<li>Technisches Geschick im Umgang mit Consumer Devices; Du brauchst also KEIN technisches Studium, sondern musst Dich nur gut mit Computer, Handy und Co auskennen.</li>\n<li>Ein Android-Smartphone</li>\n<li>Pünktlichkeit und Zeitmanagement</li>\n<li>Ein positives Erscheinungsbild</li>\n<li>Hilfsbereitschaft</li>\n</ul>\n<h2>Benefits</h2>\n<ul>\n<li>Faire Bezahlung (36€/h) + ggf. Anfahrtspauschele</li>\n<li>Flexible Arbeitszeiten (Du entscheidest, welche Aufträge Du übernehmen möchtest</li>\n<li>Auswahl aus einer Vielzahl unterschiedlicher, spannender Aufträge</li>\n</ul>\n<p><strong>Klingt nicht schlecht? So einfach geht’s:</strong></p>\n<ul>\n<li>Bewirb Dich bei uns</li>\n<li>Wir melden uns bei Dir und laden Dich zu einem Gespräch ein</li>\n<li>Im Zuge des Gesprächs zeigst Du uns Dein technisches Geschick und erhältst genaue Informationen zu unserem Konzept</li>\n</ul>\n<p>Find more <a href="https://www.arbeitnow.com/english-speaking-jobs">English Speaking Jobs in Germany</a> on Arbeitnow</a>',
#   'remote': False,
#   'url': 'https://www.arbeitnow.com/jobs/companies/helferline-gmbh/technischer-support-fur-privatpersonen-40eur-h-trier-233211',
#   'tags': ['IT'],
#   'job_types': ['Freelance'],
#   'location': 'Trier',
#   'created_at': 1739818143},
#  {'slug': 'full-stack-developer-winterberg-28994',
#   'company_name': 'apomap GmbH',
#   'title': 'Full Stack Developer (m/w/d)',
#   'description': '<p><strong>Du hast Lust, als Entwickler:in etwas zu bewegen?</strong> Wir bei <strong>apomap</strong> revolutionieren die <strong>letzte Meile der Apothekenlogistik</strong> in Deutschland mit unserer modernen <strong>SaaS-Plattform</strong>. Unser Fokus liegt auf <strong>intelligenter Routenoptimierung, effizientem Liefermanagement und nahtlosen Integrationen</strong>, damit Apotheken ihre Kund:innen schneller und zuverlässiger versorgen können.</p>\n<p><strong>apomap versteht sich als Channel-Management-Plattform für die Apothekenlogistik</strong> – wir entwickeln smarte Softwarelösungen, die Prozesse vereinfachen, Zeit sparen und eine <strong>reibungslosere Zusammenarbeit zwischen Apotheken, Lieferdiensten und Endkund:innen</strong> ermöglichen.</p>\n<p>Unser Team arbeitet in <strong>agilen Sprints</strong>, um kontinuierlich <strong>neue und innovative Funktionen zu entwickeln, die die Effizienz in der Apothekenlogistik steigern</strong>. Dabei legen wir großen Wert auf <strong>eine familiäre Unternehmenskultur</strong>, in der <strong>offene Kommunikation und Teamgeist</strong> im Mittelpunkt stehen. Das <strong>Wohlbefinden unseres Teams</strong> ist uns besonders wichtig – deshalb bieten wir unter anderem eine <strong>Wellpass-Mitgliedschaft</strong> für zusätzliche Vorteile über die Arbeit hinaus.</p>\n<p><em>English:</em></p>\n<p><strong>Are you eager to make an impact as a developer?</strong> At <strong>apomap</strong>, we are revolutionizing the <strong>last mile of pharmacy logistics</strong> in Germany with our modern <strong>SaaS platform</strong>. Our focus is on <strong>smart route optimization, efficient delivery management, and seamless integrations</strong>, enabling pharmacies to serve their customers faster and more reliably.</p>\n<p><strong>apomap positions itself as a channel management platform for pharmacy logistics</strong> – we develop smart software solutions that <strong>simplify processes, save time, and enable smooth collaboration between pharmacies, delivery services, and end customers</strong>.</p>\n<p>Our team works in <strong>agile sprints</strong> to continuously develop <strong>new and innovative features that enhance efficiency in pharmacy logistics</strong>. We place great importance on <strong>a family-like company culture</strong>, where <strong>open communication and teamwork</strong> are at the core. The <strong>well-being of our team</strong> is a top priority – that’s why we offer <strong>a Wellpass membership</strong> for additional benefits beyond work.</p>\n<h2>Aufgaben</h2>\n<p>Wir suchen eine:n erfahrene:n <strong>Full Stack Developer</strong> mit einem starken Fokus auf <strong>Frontend-Entwicklung</strong>, um unser wachsendes Team zu verstärken. Deine Hauptaufgabe besteht darin, <strong>intuitive und ansprechende Benutzeroberflächen</strong> für unsere SaaS-Plattform zu entwerfen und zu entwickeln, um eine <strong>optimale User Experience</strong> sicherzustellen.</p>\n<p>Wir suchen eine Person, die <strong>Leidenschaft für die Entwicklung einzigartiger Produkte</strong> mitbringt, Wert auf <strong>Kommunikation und Dokumentation</strong> legt und in einem <strong>dynamischen, mission-driven Umfeld</strong> arbeiten möchte. <strong>Eigeninitiative und Verantwortungsbewusstsein</strong> sind essenziell – du solltest <strong>Entscheidungen treffen, Aufgaben selbstständig übernehmen und Projekte aktiv vorantreiben</strong> können.</p>\n<p><strong>Deine Aufgaben</strong></p>\n<ul>\n<li>Entwicklung und Wartung von <strong>Frontend-Funktionen</strong> mit <strong>React, Typescript und TailwindCSS</strong>, um eine erstklassige User Experience zu gewährleisten.</li>\n<li>Enge Zusammenarbeit mit <strong>Produkt- und Designteams</strong>, um Anforderungen in hochwertige Features umzusetzen.</li>\n<li>Entwicklung <strong>wiederverwendbarer und effizienter UI-Komponenten</strong>, die geräteübergreifend nahtlos funktionieren.</li>\n<li>Sicherstellung einer reibungslos ...
#   'remote': False,
#   'url': 'https://www.arbeitnow.com/jobs/companies/apomap-gmbh/full-stack-developer-winterberg-28994',
#   'tags': ['Software Development'],
#   'job_types': [],
#   'location': 'Winterberg',
#   'created_at': 1739818143},
#  {'slug': 'interner-berater-it-infrastructure-mit-mindestens-6-jahren-erfahrung-kempten-34038',
#   'company_name': 'intellitext SprachenService',
#   'title': 'Interner Berater IT Infrastructure mit mindestens 6 Jahren Erfahrung (m/w/d)',
#   'description': '<p>Standort: Allgäu</p>\n<p>Start: Schnellstmöglich</p>\n<p>Kapazität: Vollzeit </p>\n<p>Branche: Nahrungsmittel</p>\n<p>Position: Interner Berater IT Infrastructure mit mindestens 6 Jahren Erfahrung (m/w/d)</p>\n<p>Ein traditionsreiches mittelständisches Familienunternehmen mit Hauptsitz im Allgäu, bekannt als führender Lebensmittelhersteller, sucht Sie als erfahrenen Internen Berater für IT Infrastructure.</p>\n<p>Verbinden Sie Ihre berufliche Entwicklung mit einem Lebensumfeld, das Raum für Qualität, Gemeinschaft und persönliche Entfaltung bietet. Das Allgäu ist neben seiner beeindruckenden Landschaft ein Ort für Menschen, die Wert auf Lebensqualität legen und ein Zuhause für sich und ihre Familie suchen. Ob Sie als Rückkehrer Ihre Heimat neu entdecken wollen oder eine ausgewogene Work-Life-Balance suchen – hier verbinden sich berufliche Perspektiven mit einem Umfeld hoher Lebensqualität.</p>\n<h2>Aufgaben</h2>\n<p>Aufgabe und Verantwortungen</p>\n<p>· Verwaltung und Wartung der Netzwerk- und Rechenzentrumsinfrastruktur.</p>\n<p>· Überwachung der Netzwerkleistung und Fehlerbehebung bei Problemen.</p>\n<p>· Implementierung und Verwaltung von Sicherheitsmaßnahmen.</p>\n<p>· Planung und Durchführung von Upgrades und Migrationen.</p>\n<p>· Zusammenarbeit mit anderen IT-Teams zur Optimierung der Systemleistung.</p>\n<p>· Dokumentation der Netzwerkarchitektur und -prozesse.</p>\n<p>· Installation und Konfiguration von Servern und Speichersystemen.</p>\n<p>· Überwachung von Verwaltung der Rechenzentrumskühlung und -stromversorgung.</p>\n<p>· Durchführung regelmäßiger Backups und Wiederherstellungstests.</p>\n<p>· Sicherstellung der physischen Sicherheit des Rechenzentrums.</p>\n<p>· Verwaltung von Virtualisierungsumgebungen und Cloud-Integration.</p>\n<p>· Planung und Umsetzung von IT-Projekten.</p>\n<p>· Evaluierung und Implementierung von neuen Lösungen in Zusammenarbeit mit den Fachabteilungen.</p>\n<p>· Fehlersuche und Behebung von Problemen im 2nd-Level-Support.</p>\n<h2>Qualifikation</h2>\n<p>Qualifikation / Profil</p>\n<p>· Abgeschlossenes Studium der Informatik oder eine vergleichbare Qualifikation.</p>\n<p>· Mehrjährige Berufserfahrung in der Netzwerk- und Rechenzentrumsadministration.</p>\n<p>· Fundierte Kenntnisse in Netzwerktechnologien (z. B. TCP/IP, DNS, DHCP, VPN).</p>\n<p>· Kenntnisse in der Verwaltung von Firewalls und Sicherheitsprotokollen.</p>\n<p>· Ausgeprägte Problemlösungsfähigkeiten und analytisches Denken.</p>\n<p>· Teamfähigkeit und gute Kommunikationsfähigkeiten.</p>\n<p>Find <a href="https://www.arbeitnow.com/">Jobs in Germany</a> on Arbeitnow</a>',
#   'remote': False,
#   'url': 'https://www.arbeitnow.com/jobs/companies/intellitext-sprachenservice/interner-berater-it-infrastructure-mit-mindestens-6-jahren-erfahrung-kempten-34038',
#   'tags': ['IT'],
#   'job_types': ['berufserfahren'],
#   'location': 'Kempten',
#   'created_at': 1739818143},
#  {'slug': 'senior-security-consultant-kempten-486103',
#   'company_name': 'intellitext SprachenService',
#   'title': 'Senior Security Consultant (m/w/d)',
#   'description': '<p>Standort: Allgäu<br>\nStart: Schnellstmöglich<br>\nKapazität: Vollzeit<br>\nBranche: Nahrungsmittel<br>\nPosition: Senior Security Consultant (m/w/d)  </p>\n<p>Das Familienunternehmen in dritter Generation mit Hauptsitz im Allgäu (1.200 Mitarbeiter) gilt als führender Hersteller in den Segmenten Käsespezialitäten und hochwertigen getrockneten Milch- und Molkederivaten. Als einer der erfolgreichsten Unternehmensgruppen der deutschen Milchwirtschaft verkauft das Unternehmen rund 50 Weichkäsespezialitäten in über 55 Ländern.<br>\nDas Unternehmen bietet für seine Mitarbeiter sehr gute Sozialleistungen und ein höchst interessantes Vergütungspaket.</p>\n<h2>Aufgaben</h2>\n<p>Aufgabe und Verantwortungen:<br>\nDie IT-Sicherheitslösungen sind technisch zu betreuen, weiterzuentwickeln und gleichzeitig auch Neueinführungen zu begleiten.<br>\nSysteme wie EDR, NDR und SIEM sind auf ein neues Niveau zu bringen.<br>\nDie internen IT-Sicherheitsrichtlinien werden auf Aktualität geprüft und weiterentwickelt, bei Bedarf auch neu erstellt.<br>\nDie ISO-Norm 27001 ist zu konzeptionieren und zu implementieren und die regelmäßigen Audits sind zu begleiten.<br>\nEnge Zusammenarbeit mit den IT-Sicherheitsbeauftragten, sowohl intern als auch extern.</p>\n<h2>Qualifikation</h2>\n<p>Qualifikation / Profil:<br>\nEine abgeschlossene Ausbildung zum Fachinformatiker, eine vergleichbare Qualifikation oder auch ein abgeschlossenes Studium zum Bachelor Wirtschaftsinformatik oder Informatik.<br>\nFundierte praktische Erfahrung auf dem Gebiet von IT-Sicherheitslösungen.<br>\nKenntnisse der Prozesse einer Zertifizierung, im besten Fall Erfahrungen bei ihrer Begleitung.<br>\nVernetzte Denkweise, analytische Veranlagung und Verständnis für die Zusammenhänge.</p>\n<p>Find more <a href="https://www.arbeitnow.com/english-speaking-jobs">English Speaking Jobs in Germany</a> on Arbeitnow</a>',
#   'remote': False,
#   'url': 'https://www.arbeitnow.com/jobs/companies/intellitext-sprachenservice/senior-security-consultant-kempten-486103',
#   'tags': ['IT'],
#   'job_types': ['berufserfahren'],
#   'location': 'Kempten',
#   'created_at': 1739814543},
#  {'slug': 'dgnb-auditor-consultant-bnb-sachverstandiger-koordinator-esg-manager-bnk-birn-lnb-auditor-energieberater-bauphysiker-hybrides-arbe-355200',
#   'company_name': 'Ingenieurbüro Quarti GmbH',
#   'title': 'DGNB-Auditor/Consultant - BNB Sachverständiger/Koordinator -  ESG-Manager - BNK/BiRN/LNB-Auditor - Energieberater - Bauphysiker (m/w/d)  Hybrides Arbeiten in Baden',
#   'description': '<p><strong>DGNB? BNB? ESG? BNK? BNG? LNB? QNG?</strong><br>\nSie wissen was hinter diesen Abkürzungen steckt und haben sich in einem der Bereiche schon qualifiziert? Sie kommen aus der Bauphysik, dem konstruktiven Ingenieurbau oder der Energieberatung? Sie wollen sich im Nachhaltigkeitsbereich weiterentwickeln? Dann kommen Sie zu uns.</p>\n<p>Wir sind seit über 40 Jahren ein gefragter Partner für Tragwerks- und Energieplanung in Baden. Wir planen vielseitig, sowohl kleinere, als auch umfangreiche Projekte: Wohn-, Industrie- und Gewerbegebäude im Neubau oder Bestand sowie denkmalgeschützte, historische Bauwerke. Unsere Spezialität: Effiziente Fachplanung für nachhaltige Gebäude.</p>\n<p>Zur Verstärkung unseres Teams suchen wir ab sofort weitere Kolleg*innen:</p>\n<p><strong>DGNB-Auditor/Consultant - BNB Sachverständiger/Koordinator -</strong><br>\n<strong>ESG-Manager - BNK/BiRN/LNB-Auditor - Energieberater - Bauphysiker (m/w/d)</strong><br>\nHybrides Arbeiten in Baden</p>\n<h2>Aufgaben</h2>\n<ul>\n<li>Durchführung und Koordination von Zertifizierungsprojekten zu Systemen des nachhaltigen Bauens (QNG/DGNB/BNB/ESG/BNK/BiRN/LNB)</li>\n<li>Bearbeitung der Fachplanung Nachhaltigkeit (Kriterienbewertungen, Ökobilanzierung, Materialökologie, zirkuläres Bauen…)</li>\n<li>Beratung von Bauherren, Architekten, Planungsteams und Projektentwicklern in Bezug auf nachhaltige Gebäudeplanung, -optimierung und -umsetzung</li>\n<li>Bearbeitung von Kundenanfragen in der Energieberatung und komplette Abwicklung von der Kundenberatung bis zur Fertigstellung des Projekts</li>\n<li>Energieberatung und Konzepte für Privat-, Kommunal- und Gewerbekunden erstellen – auch für historische Bausubstanz</li>\n<li>Bearbeitung von Fachplanungen im Leistungsbild Wärmeschutz- und Energiebilanzierung </li>\n<li>Thermische Bauphysik – Feuchteschutz, Wärmebrücken, sommerlicher Wärmeschutz</li>\n<li>Fachplanungen zu den Förderrichtlinien (BEG, KfW, BAFA…)</li>\n<li>Unterstützung unserer Kunden bei Förderanträgen (Fördermittelmanagement)</li>\n<li>Baubegleitung / Vor-Ort-Kontrollen</li>\n<li>Bauakustik- und Raumakustikfachplanung, bauphysikalische Spezialthemen wie z.B. thermische Raum- oder Gebäudesimulation</li>\n</ul>\n<h2>Qualifikation</h2>\n<ul>\n<li>Qualifikation als DGNB Auditor, BNB-Sachverständiger, Birn-Auditor<br>\noder LNB-Experte<br>\nalternativ Qualifikation als DGNB Consultant, BNB-Koordinator, ESG Manager<br>\nund<br>\nein erfolgreich abgeschlossenes technisches Studium im Bauingenieurwesen, Architektur, Gebäudetechnik, Baubetriebswesen, nachhaltigen Bauen oder in einem verwandten Themenbereich</li>\n<li>fachspezifische Kenntnisse im Bereich Fachplanung Nachhaltigkeit / Energieberatung und erste Erfahrungen in der Beratung zum nachhaltigen Bauen und der Projektleitung</li>\n<li>wünschenswert: Erfahrung im Schall-, Wärme- und Feuchteschutz</li>\n<li>kommunikative, lösungsorientierte und kostenbewusste Arbeitsweise</li>\n<li>Flexibilität und Zuverlässigkeit</li>\n</ul>\n<h2>Benefits</h2>\n<p>Darum sollten Sie zu uns kommen:</p>\n<ul>\n<li>Erfahrenes Spezialisten-Team von 20 Mitarbeiter*innen mit flacher Hierarchie und <strong>kollegialer Atmosphäre</strong></li>\n<li>Vielseitige, <strong>abwechslungsreiche</strong> Projekte</li>\n<li>Chance, das Geschäftsfeld <strong>„Nachhaltigkeitsberatung“ mit auszubauen</strong></li>\n<li><strong>Hybrides Arbeiten</strong> mit teilweise Homeoffice auf Wunsch möglich</li>\n<li>Regionale Kunden, kurze Wege</li>\n<li>Modern ausgestattete, ergonomische Büros und attraktive Sozialleistungen</li>\n<li>Hohe Lebensqualität in Offenburg, der sonnenreichsten Stadt Deutschlands</li>\n</ul>\n<p><strong>Lust, bei uns die Nachhaltigkeitsprojekte vorwärts zu bringen?</strong> Dann schicken Sie uns Ihre Unterlagen am liebsten digital. Fragen vorab? Ralf Quarti beantwortet sie Ihnen gerne telefonisch.</p>\n<p>Find <a href="https://www.arbeitnow.com/">Jobs in Germany</a> on Arbeitnow</a>',
#   'remote': False,
#   'url': 'https://www.arbeitnow.com/jobs/companies/ingenieurburo-quarti-gmbh/dgnb-auditor-consultant-bnb-sachverstandiger-koordinator-esg-manager-bnk-birn-lnb-auditor-energieberater-bauphysiker-hybrides-arbe-355200',
#   'tags': ['Construction Engineering'],
#   'job_types': ['berufseinstieg'],
#   'location': 'Offenburg',
#   'created_at': 1739814543},
#  {'slug': 'hr-manager-berlin-191808',
#   'company_name': 'Eberhardt Service Group GmbH',
#   'title': 'HR Manager',
#   'description': '<p><strong>Eberhardt Service</strong> ist der innovative <strong>360°-Dienstleister</strong> für Ihre Immobilien und Liegenschaften, bei dem Handwerkskunst mit digitalen Lösungen verschmelzen. Als <strong>Facility-Management-Unternehmen</strong> ermöglicht Ihnen Eberhardt Service, Ihr <strong>Immobilienportfolio</strong> ganzheitlich und <strong>professionell</strong> zu <strong>bewirtschaften</strong>, Möglichkeiten zur <strong>Kosteneinsparung</strong> zu <strong>identifizieren</strong> und diese schnell und aktiv anzugehen.</p>\n<h2>Aufgaben</h2>\n<ul>\n<li>Du übernimmst die Verantwortung für den gesamten Recruiting-Prozess – von der Stellenanzeige bis hin zur erfolgreichen Integration neuer Mitarbeiter.</li>\n<li>Du bist zuständig für die strategische Personalplanung und die Weiterentwicklung unserer HR-Strategien.</li>\n<li>Du berätst und unterstützt Führungskräfte und Mitarbeiter bei personalrelevanten Themen.</li>\n<li>Du bist verantwortlich für das Personalmanagement und die Weiterentwicklung der Unternehmenskultur.</li>\n<li>Du implementierst HR-Programme und -Projekte, die die Zufriedenheit und Bindung unserer Mitarbeiter fördern.</li>\n<li>Du unterstützt bei der Entgeltgestaltung und der Durchführung von Personalentwicklungsmaßnahmen.</li>\n<li>Du wirkst aktiv bei der Weiterentwicklung des Arbeitsumfelds und der Arbeitgebermarke mit.</li>\n</ul>\n<h2>Qualifikation</h2>\n<ul>\n<li>Du hast ein abgeschlossenes Studium im Bereich Human Resources, Betriebswirtschaftslehre oder eine vergleichbare Ausbildung.</li>\n<li>Du bringst 5+ Jahre Berufserfahrung im Personalwesen mit, idealerweise in einer vergleichbaren Branche.</li>\n<li>Du hast ausgeprägte Kommunikationsfähigkeiten und eine hohe Serviceorientierung.</li>\n<li>Du arbeitest selbstständig, strukturiert und lösungsorientiert.</li>\n<li>Du hast Erfahrung in der Entwicklung und Umsetzung von HR-Strategien und Projekten.</li>\n<li>Du hast eine hohe IT-Affinität und bist sicher im Umgang mit modernen HR-Systemen.</li>\n</ul>\n<h2>Benefits</h2>\n<p>Wir bieten ein unbefristetes Arbeitsverhältnis in einem erfolgreichen und wachstumsorientierten Unternehmen; ein attraktives Gehaltspaket mit vielen Zusatzleistungen; vielfältige Weiterbildungs- und Entwicklungsmöglichkeiten sowie ein angenehmes Arbeitsumfeld in einem motivierten und kollegialen Team. Unser regelmäßiges Sip&#x26;Social-event und eine offene Unternehmenskultur gehören natürlich auch dazu.</p>\n<p>Hast du Lust, die Zukunft eines erfolgreichen Facility- Management- Unternehmens aktiv mitzugestalten und dich in einem spannenden HR-Umfeld zu entfalten? Dann freuen wir uns darauf, dich kennenzulernen! Bewirb dich jetzt und werde ein wertvoller Teil der Eberhardt Service Group. Wir bieten dir den Raum, dich zu entwickeln, zu wachsen und gemeinsam mit uns erfolgreich zu sein. Wir freuen uns auf deine Bewerbung!</p>\n<p>Find <a href="https://www.arbeitnow.com/">Jobs in Germany</a> on Arbeitnow</a>',
#   'remote': False,
#   'url': 'https://www.arbeitnow.com/jobs/companies/eberhardt-service-group-gmbh/hr-manager-berlin-191808',
#   'tags': ['Management', 'Team Leader'],
#   'job_types': ['teamleitung'],
#   'location': 'Berlin',
#   'created_at': 1739814543},
#  {'slug': 'finance-manager-at-ewor-berlin-361645',
#   'company_name': 'EWOR GmbH',
#   'title': 'Finance Manager @ EWOR (m/f/d)',
# ...
#   'description': '<div class="content-intro"><p><img src="https://i.ibb.co/pfmZqnk/Atolls-Banner-01-Greenhouse-1400x300-2x.png" alt="" width="500" height="107"></p>\n<hr>\n<h3>Atolls is the world\'s largest community-driven shopping platform, active in over 20 markets worldwide.</h3>\n<p>After rebranding from Global Savings Group to Atolls, we\'ve grown from a coupon provider into a&nbsp;<strong data-stringify-type="bold">global powerhouse</strong>, empowering consumers at every step of their shopping journeys. As a trusted destination, we help millions make smarter, more rewarding spending decisions through savings, cashback, deals, product inspiration, and reviews. Our mission is to support consumers from&nbsp;<strong data-stringify-type="bold">Anywhere to Purchase (A to P)</strong>, making shopping simpler, smarter, and more enjoyable.</p>\n<p>Our team of over 1,000 colleagues, representing 70 nationalities across 10 countries, works together to <strong data-stringify-type="bold">build</strong>&nbsp;digital products that transform the shopping experience. We foster a culture of innovation, learning, and collaboration, giving you the&nbsp;<strong data-stringify-type="bold">opportunity to grow</strong>, lead, and make meaningful contributions. Whether you\'re shaping products or improving user experiences, you\'ll be empowered to leave your mark and drive real impact.</p>\n<p>Joining Atolls means becoming part of a global team that is constantly evolving and creating platforms relied on by millions of users for confident, seamless shopping experiences.</p></div><h3>&nbsp;</h3>\n<h3><span style="color: rgb(0, 0, 0);"><strong>About this role :&nbsp;</strong></span></h3>\n<p><span style="color: rgb(0, 0, 0);">We are looking for a <strong>Working Student Social Media Assistant</strong> in <strong>Berlin&nbsp;</strong>to support and strengthen our Marketing team for the Dutch market by<strong data-start="128" data-end="229"> </strong>posting, and optimizing content across our platforms to increase reach and app retention.<br><br>This is an exciting opportunity to gain hands-on experience in a fast-paced environment, collaborating with passionate professionals who are shaping the future of shopping. At Atolls, you\'ll be empowered to grow, innovate, and contribute to meaningful projects that have a real impact.</span></p>\n<ul>\n<li style="color: rgb(0, 0, 0);"><span style="color: rgb(0, 0, 0);">This is a <strong data-start="416" data-end="441">20-hour-per-week (including weekends),</strong> allows you to&nbsp; from our Berlin headquarters and remotely.&nbsp;&nbsp;</span></li>\n</ul>\n<h3><span style="color: rgb(0, 0, 0);"><strong><br></strong><strong>Responsibilities:&nbsp;</strong></span></h3>\n<ul>\n<li style="color: rgb(0, 0, 0);" data-pm-slice="1 1 []"><span style="color: rgb(0, 0, 0);">Share the best bargains on social media, primarily Instagram, to engage and inform our audience.</span></li>\n<li style="color: rgb(0, 0, 0);" data-pm-slice="1 1 []"><span style="color: rgb(0, 0, 0);">Create and post daily stories on Instagram and Facebook to share the best deals on our Instagram and Facebook pages (stories &amp; posts)</span></li>\n<li style="color: rgb(0, 0, 0);" data-pm-slice="1 1 []">Optimize reach across various social media platforms and maximize engagement.</li>\n<li data-stringify-indent="0" data-stringify-border="0">Analyse content performance on all our social media channels.</li>\n<li data-stringify-indent="0" data-stringify-border="0">Work on retention campaigns for our own platform.</li>\n<li style="color: rgb(0, 0, 0);" data-pm-slice="1 1 []"><span style="color: rgb(0, 0, 0);">Help to create and produce engaging content for our channels.</span></li>\n<li style="color: rgb(0, 0, 0);" data-pm-slice="1 1 []"><span style="color: rgb(0, 0, 0);">Communicate with followers, providing support and fostering communication.</span></li>\n</ul>\n<h3><span style="color: rgb(0, 0, 0);"><strong><br>Your Profile :&nbsp;</strong></ ...
#   'remote': False,
#   'url': 'https://www.arbeitnow.com/jobs/companies/atolls/working-student-social-media-assistant-berlin-386728',
#   'tags': [],
#   'job_types': [],
#   'location': 'Berlin, Berlin, Germany',
#   'created_at': 1739803514},
#  {'slug': 'bauingenieur-leipzig-435503',
#   'company_name': 'immcraft GmbH',
#   'title': 'Bauingenieur (m/w/d)',
#   'description': '<p>Bist du bereit, deine Karriere auf das nächste Level zu heben? Als Bauleiter/Bauleiterin (m/w/d) bei immcraft GmbH wirst du Teil eines dynamischen Teams, das die Immobilienwelt revolutioniert. Unser Unternehmen, spezialisiert auf die Sanierung und Modernisierung von Wohnungen, setzt Maßstäbe in der Bestandsoptimierung von Mehrfamilienhäusern. Wir bieten dir die Chance, in einem innovativen Arbeitsumfeld mit erstklassigen Entwicklungsmöglichkeiten zu wachsen. Dabei legen wir Wert auf unsere Werte wie Innovation, Kreativität und gegenseitigen Respekt. Du wirst die Verantwortung für spannende Projekte tragen und dabei alle Gewerke aus einer Hand koordinieren. Wenn du eine Leidenschaft für Herausforderungen hast und in einer unterstützenden Community arbeiten möchtest, dann freuen wir uns darauf, gemeinsam mit dir unsere Mission zum Erfolg zu führen. Werde Teil von immcraft und gestalte die Zukunft des Wohnens mit!</p>\n<h2>Aufgaben</h2>\n<ul>\n<li>Planung und Koordination von Bauprojekten, um sicherzustellen, dass alles reibungslos abläuft.</li>\n<li>Überwachung der Baufortschritte vor Ort und Sicherstellen der Einhaltung von Qualitätsstandards.</li>\n<li>Kommunikation mit allen Beteiligten, einschließlich Auftragnehmern und Lieferanten, um einen nahtlosen Ablauf zu gewährleisten.</li>\n<li>Identifizieren und Lösen von Problemen, die während des Bauprozesses auftreten können.</li>\n<li>Sicherstellung, dass alle Sicherheitsvorschriften und Umweltstandards eingehalten werden.</li>\n</ul>\n<h2>Qualifikation</h2>\n<ul>\n<li>Abgeschlossenes Studium im Bauingenieurwesen oder eine vergleichbare Qualifikation</li>\n<li>Mehrjährige Erfahrung in der Bauleitung, idealerweise im Bereich Sanierung und Modernisierung</li>\n<li>Ausgeprägte Kommunikations- und Teamfähigkeit</li>\n<li>Selbstständige, strukturierte und zielorientierte Arbeitsweise</li>\n<li>Sicherer Umgang mit MS Office und bauspezifischen Softwareanwendungen</li>\n</ul>\n<h2>Benefits</h2>\n<ul>\n<li>Attraktive Vergütung und zusätzliche Leistungen</li>\n<li>Spannende, abwechslungsreiche Aufgaben</li>\n<li>Möglichkeiten zur persönlichen und beruflichen Weiterentwicklung</li>\n<li>Angenehmes Arbeitsumfeld in einem motivierten Team</li>\n</ul>\n<p>Werde Bauleiter/Bauleiterin bei immcraft GmbH! Gestalte die Zukunft der Immobilienbranche in einem innovativen Team. Bewirb dich jetzt und bringe deine Karriere auf das nächste Level!</p>\n<p>Find more <a href="https://www.arbeitnow.com/english-speaking-jobs">English Speaking Jobs in Germany</a> on Arbeitnow</a>',
#   'remote': False,
#   'url': 'https://www.arbeitnow.com/jobs/companies/immcraft-gmbh/bauingenieur-leipzig-435503',
#   'tags': ['Engineering'],
#   'job_types': [],
#   'location': 'Leipzig',
#   'created_at': 1739800143},
#  {'slug': 'werkstudentin-im-bereich-offentlichkeitsarbeit-eventmanagement-bochum-400198',
#   'company_name': 'Bochumer Institut Für Technologie gGmbH',
#   'title': 'Werkstudent:in (m/w/d) im Bereich Öffentlichkeitsarbeit & Eventmanagement',
#   'description': '<p>Du studierst und suchst eine spannende Werkstudentenstelle, in der du deine kreativen Ideen einbringen kannst? Dann bist Du bei uns genau richtig! Wir sind ein junges und dynamisches Forschungsinstitut mit Sitz im Ruhrgebiet und suchen eine:n Werkstudent:in, die:der uns in der Öffentlichkeitsarbeit sowie bei der Planung unseres jährlichen Data Science Ruhrgebiet Kongresses (#DSRuhrgebiet) unterstützt.</p>\n<h2>Aufgaben</h2>\n<ul>\n<li>Erstellung von Foto- und Videomaterial für unsere Kanäle</li>\n<li>Verfassen und Publizieren von Social-Media-Beiträgen (LinkedIn &#x26; Instagram)</li>\n<li>Betreuung und Pflege unserer Social-Media-Kanäle</li>\n<li>Gestaltung von Designs für Marketingmaterialien, Werbegeschenke und Event-Merchandise</li>\n<li>Unterstützung bei der Planung und Umsetzung unserer Veranstaltungsreihe #DSRuhrgebiet</li>\n<li>Begleitung und Dokumentation von Messebesuchen und Veranstaltungen</li>\n<li>Verfassen von Blogbeiträgen zu aktuellen Themen und Events</li>\n<li>Entwicklung und Umsetzung von Werbemaßnahmen</li>\n<li>Recherche und Vorschläge für neue Formate und Kooperationen zur Steigerung unserer Sichtbarkeit</li>\n</ul>\n<h2>Qualifikation</h2>\n<ul>\n<li>Du bist immatrikulierte:r Student:in, idealerweise in einem medien-, kommunikations- oder marketingnahen Studiengang</li>\n<li>Erste Erfahrung im Bereich Social Media Management oder Content Creation</li>\n<li>Kreativität und ein Gespür für Trends in den sozialen Medien</li>\n<li>Grundkenntnisse in Grafikdesign (z. B. Canva, Affinity Photo/Designer, Figma oder ähnliche Tools)</li>\n<li>Sehr gute Deutschkenntnisse in Wort und Schrift</li>\n<li>Strukturierte und eigenständige Arbeitsweise</li>\n<li>Teamfähigkeit und Spaß an der Organisation von Events</li>\n</ul>\n<h2>Benefits</h2>\n<ul>\n<li>Fokus auf Remote Work (mindestens 1 Tag pro Woche vor Ort und je nach Bedarf)</li>\n<li>Einblick in die Arbeit eines innovativen Forschungsinstituts</li>\n<li>Verantwortungsvolle Aufgaben mit viel Raum für eigene Ideen</li>\n<li>Flexible Arbeitszeiten, die sich gut mit Deinem Studium vereinbaren lassen</li>\n<li>Die Möglichkeit, wertvolle Praxiserfahrung in Öffentlichkeitsarbeit und Eventmanagement zu sammeln</li>\n<li>Ein kreatives und dynamisches Arbeitsumfeld</li>\n<li>Teilnahme an spannenden Events, Messen und Netzwerktreffen</li>\n</ul>\n<p>Haben wir Dein Interesse geweckt? Dann freuen wir uns auf Deine Bewerbung! Sende uns Deinen Lebenslauf und ein kurzes Motivationsschreiben an karriere(at)bo-i-t. de mit dem Betreff „Bewerbung Werkstudent:in Öffentlichkeitsarbeit“.</p>\n<p>Wir freuen uns darauf, Dich kennenzulernen!</p>\n<p>Deine Fragen beantwortet Jan Treffon gerne via E-Mail jan.treffon(at)bo-i-t. de oder telefonisch unter 0234 - 622 086 77.</p>\n<p>Find <a href="https://www.arbeitnow.com/">Jobs in Germany</a> on Arbeitnow</a>',
#   'remote': False,
#   'url': 'https://www.arbeitnow.com/jobs/companies/bochumer-institut-fur-technologie-ggmbh/werkstudentin-im-bereich-offentlichkeitsarbeit-eventmanagement-bochum-400198',
#   'tags': ['Marketing and Communication'],
#   'job_types': ['Working student'],
#   'location': 'Bochum',
#   'created_at': 1739800143},
#  {'slug': 'servicetechniker-elektrotechnik-40000-bis-55000-eur-pa-bochum-18617',
#   'company_name': 'Riverstate Premium Recruiting',
#   'title': 'Servicetechniker Elektrotechnik (m/w/d) - 40.000 bis 55.000 € p.a.',
#   'description': '<p>Sind Sie bereit, eine Schlüsselrolle in einem zukunftsorientierten Unternehmen zu übernehmen? Ein führender Anbieter im Bereich Energie- und Elektrotechnik sucht einen engagierten Servicetechniker (m/w/d) für Energieversorgungsanlagen. Nutzen Sie Ihre Chance, an bedeutenden Projekten mitzuwirken und Ihre Karriere auf das nächste Level zu bringen! Dann bewerben Sie sich jetzt auf eine unbefristete Festanstellung als</p>\n<p><strong>Servicetechniker Elektrotechnik (m/w/d) – 40.000 bis 55.000 € p.a.</strong></p>\n<h2>Aufgaben</h2>\n<ul>\n<li>Wartung, Prüfung &#x26; Instandhaltung von Transformatoren, Leistungsschaltern, Schutzgeräten &#x26; Schaltanlagen (10kV – 0,4kV)</li>\n<li>Modernisierung &#x26; Optimierung von Energieversorgungsanlagen zur Steigerung von Effizienz &#x26; Sicherheit</li>\n</ul>\n<h2>Qualifikation</h2>\n<ul>\n<li>Abgeschlossene elektrotechnische Ausbildung </li>\n<li>Erfahrung als Servicetechniker Gute Deutschkenntnisse in Wort &#x26; Schrift</li>\n</ul>\n<h2>Benefits</h2>\n<ul>\n<li><strong>Attraktive Vergütung:</strong> Bis zu 55.000 €/Jahr + Urlaubs- &#x26; Weihnachtsgeld</li>\n</ul>\n<p>und 30 Urlaubstage für Ihre Erholung</p>\n<ul>\n<li><strong>Karriere mit Perspektive:</strong> Vom Monteur bis in die Geschäftsführung – zahlreiche Aufstiegsmöglichkeiten</li>\n<li><strong>Familienfreundliches Unternehmen:</strong> Unterstützung für Ihre Kinder &#x26; Enkel (Nachhilfe, Musikerziehung, Freizeitangebote)</li>\n<li><strong>Sicheres &#x26; wertschätzendes Arbeitsumfeld:</strong> Flache Hierarchien, offene Türen &#x26; regelmäßige Firmen-Events</li>\n<li><strong>Zusätzliche Benefits:</strong> Gruppen-Unfallversicherung (privat &#x26; beruflich)</li>\n</ul>\n<p><strong>Bewerben Sie sich jetzt!</strong> Wir melden uns umgehend telefonisch bei Ihnen und begleiten Sie kompetent und zuverlässig durch den gesamten Bewerbungsprozess. </p>\n<p>Unsere Beratung ist für Sie völlig kostenlos. Bei Fragen steht Ihnen Ihre persönliche Ansprechpartnerin Julia Schneider unter +49 155 60065173 gerne zur Verfügung.</p>\n<p>Find more <a href="https://www.arbeitnow.com/english-speaking-jobs">English Speaking Jobs in Germany</a> on Arbeitnow</a>',
#   'remote': False,
#   'url': 'https://www.arbeitnow.com/jobs/companies/riverstate-premium-recruiting/servicetechniker-elektrotechnik-40000-bis-55000-eur-pa-bochum-18617',
#   'tags': ['Electrical Engineering'],
#   'job_types': [],
#   'location': 'Bochum',
#   'created_at': 1739800143},
#  {'slug': 'servicetechniker-elektrotechnik-40000-bis-55000-eur-pa-olpe-175810',
#   'company_name': 'Riverstate Premium Recruiting',
#   'title': 'Servicetechniker Elektrotechnik (m/w/d) - 40.000 bis 55.000 € p.a.',
#   'description': '<p>Sind Sie bereit, eine Schlüsselrolle in einem zukunftsorientierten Unternehmen zu übernehmen? Ein führender Anbieter im Bereich Energie- und Elektrotechnik sucht einen engagierten Servicetechniker (m/w/d) für Energieversorgungsanlagen. Nutzen Sie Ihre Chance, an bedeutenden Projekten mitzuwirken und Ihre Karriere auf das nächste Level zu bringen! Dann bewerben Sie sich jetzt auf eine unbefristete Festanstellung als</p>\n<p><strong>Servicetechniker Elektrotechnik (m/w/d) – 40.000 bis 55.000 € p.a.</strong></p>\n<h2>Aufgaben</h2>\n<ul>\n<li>Wartung, Prüfung &#x26; Instandhaltung von Transformatoren, Leistungsschaltern, Schutzgeräten &#x26; Schaltanlagen (10kV – 0,4kV)</li>\n<li>Modernisierung &#x26; Optimierung von Energieversorgungsanlagen zur Steigerung von Effizienz &#x26; Sicherheit</li>\n</ul>\n<h2>Qualifikation</h2>\n<ul>\n<li>Abgeschlossene elektrotechnische Ausbildung </li>\n<li>Erfahrung als Servicetechniker Gute Deutschkenntnisse in Wort &#x26; Schrift</li>\n</ul>\n<h2>Benefits</h2>\n<ul>\n<li><strong>Attraktive Vergütung:</strong> Bis zu 55.000 €/Jahr + Urlaubs- &#x26; Weihnachtsgeld</li>\n</ul>\n<p>und 30 Urlaubstage für Ihre Erholung</p>\n<ul>\n<li><strong>Karriere mit Perspektive:</strong> Vom Monteur bis in die Geschäftsführung – zahlreiche Aufstiegsmöglichkeiten</li>\n<li><strong>Familienfreundliches Unternehmen:</strong> Unterstützung für Ihre Kinder &#x26; Enkel (Nachhilfe, Musikerziehung, Freizeitangebote)</li>\n<li><strong>Sicheres &#x26; wertschätzendes Arbeitsumfeld:</strong> Flache Hierarchien, offene Türen &#x26; regelmäßige Firmen-Events</li>\n<li><strong>Zusätzliche Benefits:</strong> Gruppen-Unfallversicherung (privat &#x26; beruflich)</li>\n</ul>\n<p><strong>Bewerben Sie sich jetzt!</strong> Wir melden uns umgehend telefonisch bei Ihnen und begleiten Sie kompetent und zuverlässig durch den gesamten Bewerbungsprozess. </p>\n<p>Unsere Beratung ist für Sie völlig kostenlos. Bei Fragen steht Ihnen Ihre persönliche Ansprechpartnerin Julia Schneider unter +49 155 60065173 gerne zur Verfügung.</p>\n<p>Find more <a href="https://www.arbeitnow.com/english-speaking-jobs">English Speaking Jobs in Germany</a> on Arbeitnow</a>',
#   'remote': False,
#   'url': 'https://www.arbeitnow.com/jobs/companies/riverstate-premium-recruiting/servicetechniker-elektrotechnik-40000-bis-55000-eur-pa-olpe-175810',
#   'tags': ['Electrical Engineering'],
#   'job_types': ['berufserfahren'],
#   'location': 'Olpe',
#   'created_at': 1739800143}]

# %%
df = pd.DataFrame(data["data"])
df
# Out:
#                                                  slug  \
# 0   junior-customer-care-manager-remote-aus-deutsc...
# 1   praktikum-im-online-marketing-3-6-monate-colog...
# 2    grafikdesignerin-5-jahre-erfahrung-cologne-30003
# 3   advertising-client-success-manager-remote-berl...
# 4   bilanzbuchhalter-steuerfachangestellter-oberha...
# ..                                                ...
# 95  working-student-social-media-assistant-berlin-...
# 96                        bauingenieur-leipzig-435503
# 97  werkstudentin-im-bereich-offentlichkeitsarbeit...
# 98  servicetechniker-elektrotechnik-40000-bis-5500...
# 99  servicetechniker-elektrotechnik-40000-bis-5500...
#
#                                company_name  \
# 0                    Alphapet Ventures GmbH
# 1                                   niostem
# 2                                   niostem
# 3                                    REPLUG
# 4                     S&G Energy Group GmbH
# ..                                      ...
# 95                                   Atolls
# 96                            immcraft GmbH
# 97  Bochumer Institut Für Technologie gGmbH
# 98            Riverstate Premium Recruiting
# 99            Riverstate Premium Recruiting
#
#                                                 title  \
# 0   Junior Customer Care Manager (m/w/d) - Remote ...
# 1          Praktikum im Online Marketing (3-6 Monate)
# 2              Grafikdesigner:in (+5 Jahre Erfahrung)
# 3        Advertising Client Success Manager  (REMOTE)
# 4     Bilanzbuchhalter/Steuerfachangestellter (m/w/d)
# ..                                                ...
# 95     Working Student Social Media Assistant (m/f/x)
# 96                               Bauingenieur (m/w/d)
# 97  Werkstudent:in (m/w/d) im Bereich Öffentlichke...
# 98  Servicetechniker Elektrotechnik (m/w/d) - 40.0...
# 99  Servicetechniker Elektrotechnik (m/w/d) - 40.0...
#
#                                           description  remote  \
# 0   <h2>Deine Aufgaben</h2>\n<p>Du bist auf der Su...    True
# 1   <ul>\n<li>Wir sind ein Start-up aus Köln und h...   False
# 2   <ul>\n<li>Wir sind ein Start-up aus Köln und h...   False
# 3   <p>REPLUG is a leading mobile app marketing ag...    True
# 4   <p>Die S&#x26;G Energy Group GmbH ist ein inte...   False
# ..                                                ...     ...
# 95  <div class="content-intro"><p><img src="https:...   False
# 96  <p>Bist du bereit, deine Karriere auf das näch...   False
# 97  <p>Du studierst und suchst eine spannende Werk...   False
# 98  <p>Sind Sie bereit, eine Schlüsselrolle in ein...   False
# 99  <p>Sind Sie bereit, eine Schlüsselrolle in ein...   False
#
#                                                   url  \
# 0   https://www.arbeitnow.com/jobs/companies/alpha...
# 1   https://www.arbeitnow.com/jobs/companies/niost...
# 2   https://www.arbeitnow.com/jobs/companies/niost...
# 3   https://www.arbeitnow.com/jobs/companies/replu...
# 4   https://www.arbeitnow.com/jobs/companies/sg-en...
# ..                                                ...
# 95  https://www.arbeitnow.com/jobs/companies/atoll...
# 96  https://www.arbeitnow.com/jobs/companies/immcr...
# 97  https://www.arbeitnow.com/jobs/companies/bochu...
# 98  https://www.arbeitnow.com/jobs/companies/river...
# 99  https://www.arbeitnow.com/jobs/companies/river...
#
#                                        tags  \
# 0                [Remote, Customer Service]
# 1                        [Online Marketing]
# 2   [Graphic Arts and Communication Design]
# 3     [Remote, Marketing and Communication]
# 4                                 [Finance]
# ..                                      ...
# 95                                       []
# 96                            [Engineering]
# 97            [Marketing and Communication]
# 98                 [Electrical Engineering]
# 99                 [Electrical Engineering]
#
#                                  job_types                 location  \
# 0                         [berufseinstieg]                   Munich
# 1   [Internship, hilfstätigkeit / student]                  Cologne
# 2               [hilfstätigkeit / student]                  Cologne
# 3                                       []                   Berlin
# 4                         [berufserfahren]               Oberhausen
# ..                                     ...                      ...
# 95                                      []  Berlin, Berlin, Germany
# 96                                      []                  Leipzig
# 97                       [Working student]                   Bochum
# 98                                      []                   Bochum
# 99                        [berufserfahren]                     Olpe
#
#     created_at
# 0   1739821745
# 1   1739821745
# 2   1739821745
# 3   1739818143
# 4   1739818143
# ..         ...
# 95  1739803514
# 96  1739800143
# 97  1739800143
# 98  1739800143
# 99  1739800143
#
# [100 rows x 10 columns]

# %%
df["tags"] = df["tags"].apply(lambda x: ", ".join(x))
df["tags"]
# Out:
# 0                  Remote, Customer Service
# 1                          Online Marketing
# 2     Graphic Arts and Communication Design
# 3       Remote, Marketing and Communication
# 4                                   Finance
#                       ...
# 95
# 96                              Engineering
# 97              Marketing and Communication
# 98                   Electrical Engineering
# 99                   Electrical Engineering
# Name: tags, Length: 100, dtype: object

# %%
df["job_types"] = df["job_types"].apply(lambda x: ", ".join(x))
df["job_types"]
# Out:
# 0                           berufseinstieg
# 1     Internship, hilfstätigkeit / student
# 2                 hilfstätigkeit / student
# 3
# 4                           berufserfahren
#                       ...
# 95
# 96
# 97                         Working student
# 98
# 99                          berufserfahren
# Name: job_types, Length: 100, dtype: object

# %%
# estaba en unix
df["created_at"] = df["created_at"].apply(
    datetime.fromtimestamp
)  # le mandas la función como parámetro y ya, funciona como map!, no necesita el lambda (pero podrías)
df["created_at"]
# Out:
# 0    2025-02-17 14:49:05
# 1    2025-02-17 14:49:05
# 2    2025-02-17 14:49:05
# 3    2025-02-17 13:49:03
# 4    2025-02-17 13:49:03
#              ...
# 95   2025-02-17 09:45:14
# 96   2025-02-17 08:49:03
# 97   2025-02-17 08:49:03
# 98   2025-02-17 08:49:03
# 99   2025-02-17 08:49:03
# Name: created_at, Length: 100, dtype: datetime64[ns]

# %%
df.to_excel("job_request.xlsx")

# %%
df.to_csv("job_request.csv")
